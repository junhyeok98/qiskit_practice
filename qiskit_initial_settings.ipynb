# %%
import qiskit

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account("760736ee0e504620879e9e798e12913c")
# Out:
# configrc.store_credentials:WARNING:2023-02-23 14:34:40,601: Credentials already present. Set overwrite=True to overwrite.

# %%
overwrite=True

# %%
provider=IBMQ.load_account()

# %%
backend=provider.get_backend('ibmq_quito')

# %%
quantum_circuit=qiskit.circuit.library.QuantumVolume(4)

# %%
optimized_circuit=qiskit.transpile(quantum_circuit, backend)

# %%
optimized_circuit.draw()
# Out:
# global phase: 5.2549
#                                                                               »
# ancilla_0 -> 0 ───────────────────────────────────────────────────────────────»
#                ┌─────────────┐┌────┐┌─────────────┐┌────┐┌─────────────┐ ┌───┐»
#       q_0 -> 1 ┤ Rz(-2.3949) ├┤ √X ├┤ Rz(-1.4183) ├┤ √X ├┤ Rz(-1.4711) ├─┤ X ├»
#                └┬────────────┤├────┤├─────────────┤├────┤├─────────────┤ └─┬─┘»
#       q_2 -> 2 ─┤ Rz(0.1053) ├┤ √X ├┤ Rz(-1.4672) ├┤ √X ├┤ Rz(-1.2174) ├───■──»
#                 ├────────────┤├────┤├─────────────┤├────┤├─────────────┴┐     »
#       q_1 -> 3 ─┤ Rz(1.7656) ├┤ √X ├┤ Rz(-1.0044) ├┤ √X ├┤ Rz(-0.43978) ├──■──»
#                 ├───────────┬┘├────┤├─────────────┤├────┤└┬────────────┬┘┌─┴─┐»
#       q_3 -> 4 ─┤ Rz(2.984) ├─┤ √X ├┤ Rz(-1.3586) ├┤ √X ├─┤ Rz(1.1485) ├─┤ X ├»
#                 └───────────┘ └────┘└─────────────┘└────┘ └────────────┘ └───┘»
# «                                                                      »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────»
# «               ┌──────────────┐              ┌───┐┌─────────────┐┌───┐»
# «      q_0 -> 1 ┤ Rz(-0.51266) ├──────────────┤ X ├┤ Rz(0.15735) ├┤ X ├»
# «               └────┬────┬────┘┌───────────┐ └─┬─┘└────┬────┬───┘└─┬─┘»
# «      q_2 -> 2 ─────┤ √X ├─────┤ Rz(3.318) ├───■───────┤ √X ├──────■──»
# «                    ├────┤     ├───────────┴┐          ├────┤         »
# «      q_1 -> 3 ─────┤ √X ├─────┤ Rz(3.1545) ├──■───────┤ √X ├──────■──»
# «               ┌────┴────┴───┐ └────────────┘┌─┴─┐┌────┴────┴───┐┌─┴─┐»
# «      q_3 -> 4 ┤ Rz(0.53485) ├───────────────┤ X ├┤ Rz(0.29202) ├┤ X ├»
# «               └─────────────┘               └───┘└─────────────┘└───┘»
# «                                                                          »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────────»
# «               ┌──────────────┐┌────┐┌─────────────┐ ┌────┐ ┌────────────┐»
# «      q_0 -> 1 ┤ Rz(-0.42166) ├┤ √X ├┤ Rz(-1.0598) ├─┤ √X ├─┤ Rz(1.6056) ├»
# «               └┬────────────┬┘├────┤├─────────────┴┐├────┤┌┴────────────┤»
# «      q_2 -> 2 ─┤ Rz(2.0962) ├─┤ √X ├┤ Rz(-0.26818) ├┤ √X ├┤ Rz(-2.4831) ├»
# «                ├───────────┬┘ ├────┤├──────────────┤├────┤└┬───────────┬┘»
# «      q_1 -> 3 ─┤ Rz(2.058) ├──┤ √X ├┤ Rz(-0.26881) ├┤ √X ├─┤ Rz(1.269) ├─»
# «                ├───────────┤  ├────┤├──────────────┤├────┤ ├───────────┴┐»
# «      q_3 -> 4 ─┤ Rz(2.474) ├──┤ √X ├┤ Rz(-0.86869) ├┤ √X ├─┤ Rz(-3.006) ├»
# «                └───────────┘  └────┘└──────────────┘└────┘ └────────────┘»
# «                                                                          »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────────»
# «                         ┌────┐    ┌────────────┐          ┌────┐         »
# «      q_0 -> 1 ──■───────┤ √X ├────┤ Rz(3.4189) ├──■───────┤ √X ├──────■──»
# «                 │       └────┘    └────────────┘  │       └────┘      │  »
# «      q_2 -> 2 ──┼─────────────────────────────────┼───────────────────┼──»
# «               ┌─┴─┐┌─────────────┐              ┌─┴─┐┌─────────────┐┌─┴─┐»
# «      q_1 -> 3 ┤ X ├┤ Rz(0.99799) ├──────────────┤ X ├┤ Rz(0.18868) ├┤ X ├»
# «               └───┘└─────────────┘              └───┘└─────────────┘└───┘»
# «      q_3 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                            »
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌────────────┐┌────┐┌─────────────┐┌────┐ ┌────────────┐     »
# «      q_0 -> 1 ┤ Rz(1.1573) ├┤ √X ├┤ Rz(-1.7756) ├┤ √X ├─┤ Rz(2.7393) ├──■──»
# «               └────────────┘└────┘└─────────────┘└────┘ └────────────┘  │  »
# «      q_2 -> 2 ──────────────────────────────────────────────────────────┼──»
# «               ┌────────────┐┌────┐┌─────────────┐┌────┐┌─────────────┐┌─┴─┐»
# «      q_1 -> 3 ┤ Rz(3.0599) ├┤ √X ├┤ Rz(-2.4391) ├┤ √X ├┤ Rz(-1.6272) ├┤ X ├»
# «               └────────────┘└────┘└─────────────┘└────┘└─────────────┘└───┘»
# «      q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                      »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────»
# «                    ┌────┐    ┌─────────────┐          ┌────┐         »
# «      q_0 -> 1 ─────┤ √X ├────┤ Rz(-2.7795) ├──■───────┤ √X ├──────■──»
# «                    └────┘    └─────────────┘  │       └────┘      │  »
# «      q_2 -> 2 ────────────────────────────────┼───────────────────┼──»
# «               ┌─────────────┐               ┌─┴─┐┌─────────────┐┌─┴─┐»
# «      q_1 -> 3 ┤ Rz(0.75764) ├───────────────┤ X ├┤ Rz(0.38779) ├┤ X ├»
# «               └─────────────┘               └───┘└─────────────┘└───┘»
# «      q_3 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                             »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────────────»
# «               ┌────────────┐┌────┐┌──────────────┐┌────┐ ┌───────────┐ ┌───┐»
# «      q_0 -> 1 ┤ Rz(2.8903) ├┤ √X ├┤ Rz(-0.95531) ├┤ √X ├─┤ Rz(2.731) ├─┤ X ├»
# «               └────────────┘└────┘└──────────────┘└────┘ └───────────┘ └─┬─┘»
# «      q_2 -> 2 ───────────────────────────────────────────────────────────■──»
# «               ┌────────────┐┌────┐┌─────────────┐ ┌────┐┌─────────────┐     »
# «      q_1 -> 3 ┤ Rz(2.3115) ├┤ √X ├┤ Rz(-2.5355) ├─┤ √X ├┤ Rz(-1.2243) ├──■──»
# «               └────────────┘└────┘└─────────────┘ └────┘└─────────────┘┌─┴─┐»
# «      q_3 -> 4 ─────────────────────────────────────────────────────────┤ X ├»
# «                                                                        └───┘»
# «                                                                     »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────»
# «                    ┌───┐ ┌────────────┐ ┌────┐┌─────────────┐ ┌────┐»
# «      q_0 -> 1 ──■──┤ X ├─┤ Rz(2.8226) ├─┤ √X ├┤ Rz(-1.7964) ├─┤ √X ├»
# «               ┌─┴─┐└─┬─┘┌┴────────────┴┐├────┤├─────────────┴┐├────┤»
# «      q_2 -> 2 ┤ X ├──■──┤ Rz(-0.54408) ├┤ √X ├┤ Rz(-0.75847) ├┤ √X ├»
# «               ├───┤     ├─────────────┬┘├────┤├─────────────┬┘├────┤»
# «      q_1 -> 3 ┤ X ├──■──┤ Rz(0.12401) ├─┤ √X ├┤ Rz(-2.9262) ├─┤ √X ├»
# «               └─┬─┘┌─┴─┐└┬────────────┤ ├────┤├─────────────┤ ├────┤»
# «      q_3 -> 4 ──■──┤ X ├─┤ Rz(1.1789) ├─┤ √X ├┤ Rz(-2.1522) ├─┤ √X ├»
# «                    └───┘ └────────────┘ └────┘└─────────────┘ └────┘»
# «                                                                      »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────»
# «               ┌──────────────┐          ┌────┐    ┌────────────┐     »
# «      q_0 -> 1 ┤ Rz(0.019833) ├──■───────┤ √X ├────┤ Rz(3.1801) ├──■──»
# «               ├──────────────┤  │       └────┘    └────────────┘  │  »
# «      q_2 -> 2 ┤ Rz(-0.17899) ├──┼─────────────────────────────────┼──»
# «               ├─────────────┬┘┌─┴─┐┌─────────────┐              ┌─┴─┐»
# «      q_1 -> 3 ┤ Rz(-2.9914) ├─┤ X ├┤ Rz(0.74104) ├──────────────┤ X ├»
# «               └┬────────────┤ └───┘└─────────────┘              └───┘»
# «      q_3 -> 4 ─┤ Rz(2.4163) ├────────────────────────────────────────»
# «                └────────────┘                                        »
# «                                                                            »
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────────»
# «                   ┌────┐          ┌────────────┐┌────┐┌─────────────┐┌────┐»
# «      q_0 -> 1 ────┤ √X ├──────■───┤ Rz(-1.899) ├┤ √X ├┤ Rz(-1.7273) ├┤ √X ├»
# «                   └────┘      │   └────────────┘└────┘└─────────────┘└────┘»
# «      q_2 -> 2 ────────────────┼────────────────────────────────────────────»
# «               ┌────────────┐┌─┴─┐┌─────────────┐┌────┐┌─────────────┐┌────┐»
# «      q_1 -> 3 ┤ Rz(0.3991) ├┤ X ├┤ Rz(-1.3115) ├┤ √X ├┤ Rz(-2.6778) ├┤ √X ├»
# «               └────────────┘└───┘└─────────────┘└────┘└─────────────┘└────┘»
# «      q_3 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                        »
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────»
# «               ┌──────────────┐          ┌────┐     ┌─────────────┐     »
# «      q_0 -> 1 ┤ Rz(-0.93249) ├──■───────┤ √X ├─────┤ Rz(-2.6694) ├──■──»
# «               └──────────────┘  │       └────┘     └─────────────┘  │  »
# «      q_2 -> 2 ──────────────────┼───────────────────────────────────┼──»
# «               ┌─────────────┐ ┌─┴─┐┌──────────────┐               ┌─┴─┐»
# «      q_1 -> 3 ┤ Rz(-3.0703) ├─┤ X ├┤ Rz(-0.76482) ├───────────────┤ X ├»
# «               └─────────────┘ └───┘└──────────────┘               └───┘»
# «      q_3 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                              »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────────────»
# «                    ┌────┐         ┌─────────────┐┌────┐┌──────────────┐┌────┐»
# «      q_0 -> 1 ─────┤ √X ├──────■──┤ Rz(-2.2067) ├┤ √X ├┤ Rz(-0.23926) ├┤ √X ├»
# «                    └────┘      │  └─────────────┘└────┘└──────────────┘└────┘»
# «      q_2 -> 2 ─────────────────┼─────────────────────────────────────────────»
# «               ┌─────────────┐┌─┴─┐┌─────────────┐┌────┐┌─────────────┐ ┌────┐»
# «      q_1 -> 3 ┤ Rz(0.45137) ├┤ X ├┤ Rz(-2.9979) ├┤ √X ├┤ Rz(-1.8583) ├─┤ √X ├»
# «               └─────────────┘└───┘└─────────────┘└────┘└─────────────┘ └────┘»
# «      q_3 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «                                                                      »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────»
# «                ┌────────────┐┌───┐ ┌────────────┐               ┌───┐»
# «      q_0 -> 1 ─┤ Rz(2.7648) ├┤ X ├─┤ Rz(1.1275) ├───────────────┤ X ├»
# «                └────────────┘└─┬─┘ └───┬────┬───┘ ┌────────────┐└─┬─┘»
# «      q_2 -> 2 ─────────────────■───────┤ √X ├─────┤ Rz(3.2674) ├──■──»
# «               ┌─────────────┐          ├────┤    ┌┴────────────┤     »
# «      q_1 -> 3 ┤ Rz(-1.0755) ├──■───────┤ √X ├────┤ Rz(-2.5097) ├──■──»
# «               └─────────────┘┌─┴─┐┌────┴────┴───┐└─────────────┘┌─┴─┐»
# «      q_3 -> 4 ───────────────┤ X ├┤ Rz(0.77358) ├───────────────┤ X ├»
# «                              └───┘└─────────────┘               └───┘»
# «                                                                         »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────────»
# «               ┌─────────────┐ ┌───┐┌─────────────┐┌────┐┌─────────────┐ »
# «      q_0 -> 1 ┤ Rz(0.25338) ├─┤ X ├┤ Rz(-2.0914) ├┤ √X ├┤ Rz(-1.1871) ├─»
# «               └────┬────┬───┘ └─┬─┘├─────────────┤├────┤├─────────────┴┐»
# «      q_2 -> 2 ─────┤ √X ├───────■──┤ Rz(-2.2941) ├┤ √X ├┤ Rz(-0.95083) ├»
# «                    ├────┤          ├─────────────┤├────┤├─────────────┬┘»
# «      q_1 -> 3 ─────┤ √X ├───────■──┤ Rz(-2.9482) ├┤ √X ├┤ Rz(-1.4688) ├─»
# «               ┌────┴────┴────┐┌─┴─┐└┬────────────┤├────┤├─────────────┤ »
# «      q_3 -> 4 ┤ Rz(0.068656) ├┤ X ├─┤ Rz(0.6574) ├┤ √X ├┤ Rz(-1.4405) ├─»
# «               └──────────────┘└───┘ └────────────┘└────┘└─────────────┘ »
# «
# «ancilla_0 -> 0 ──────────────────────
# «               ┌────┐ ┌────────────┐
# «      q_0 -> 1 ┤ √X ├─┤ Rz(2.6368) ├─
# «               ├────┤ ├────────────┤
# «      q_2 -> 2 ┤ √X ├─┤ Rz(1.0435) ├─
# «               ├────┤┌┴────────────┴┐
# «      q_1 -> 3 ┤ √X ├┤ Rz(-0.12059) ├
# «               ├────┤├─────────────┬┘
# «      q_3 -> 4 ┤ √X ├┤ Rz(-2.0539) ├─
# «               └────┘└─────────────┘
