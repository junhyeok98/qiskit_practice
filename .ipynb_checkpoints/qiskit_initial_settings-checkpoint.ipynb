# %%
import qiskit

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account("760736ee0e504620879e9e798e12913c")
# Out:
# configrc.store_credentials:WARNING:2023-02-20 12:52:12,051: Credentials already present. Set overwrite=True to overwrite.

# %%
overwrite=True

# %%
provider=IBMQ.load_account()

# %%
backend=provider.get_backend('ibmq_quito')

# %%
quantum_circuit=qiskit.circuit.library.QuantumVolume(4)

# %%
optimized_circuit=qiskit.transpile(quantum_circuit, backend)

# %%
optimized_circuit.draw()
# Out:
# global phase: 0.16268
#                                                                                »
# ancilla_0 -> 0 ────────────────────────────────────────────────────────────────»
#                ┌─────────────┐ ┌────┐┌──────────────┐┌────┐┌─────────────┐┌───┐»
#       q_3 -> 1 ┤ Rz(-2.9566) ├─┤ √X ├┤ Rz(-0.78475) ├┤ √X ├┤ Rz(-2.6171) ├┤ X ├»
#                └┬────────────┤ ├────┤├─────────────┬┘├────┤├─────────────┤└─┬─┘»
#       q_1 -> 2 ─┤ Rz(1.4707) ├─┤ √X ├┤ Rz(-1.7322) ├─┤ √X ├┤ Rz(-1.8483) ├──■──»
#                ┌┴────────────┴┐├────┤├─────────────┤ ├────┤├─────────────┤     »
#       q_0 -> 3 ┤ Rz(-0.46429) ├┤ √X ├┤ Rz(-1.2409) ├─┤ √X ├┤ Rz(-3.0842) ├──■──»
#                └┬────────────┬┘├────┤├─────────────┴┐├────┤├─────────────┤┌─┴─┐»
#       q_2 -> 4 ─┤ Rz(0.8329) ├─┤ √X ├┤ Rz(-0.87843) ├┤ √X ├┤ Rz(-0.1742) ├┤ X ├»
#                 └────────────┘ └────┘└──────────────┘└────┘└─────────────┘└───┘»
# «                                                                       »
# «ancilla_0 -> 0 ────────────────────────────────────────────────────────»
# «               ┌──────────────┐               ┌───┐┌─────────────┐┌───┐»
# «      q_3 -> 1 ┤ Rz(-0.63696) ├───────────────┤ X ├┤ Rz(0.27336) ├┤ X ├»
# «               └────┬────┬────┘┌─────────────┐└─┬─┘└────┬────┬───┘└─┬─┘»
# «      q_1 -> 2 ─────┤ √X ├─────┤ Rz(-2.5395) ├──■───────┤ √X ├──────■──»
# «                    ├────┤     └┬────────────┤          ├────┤         »
# «      q_0 -> 3 ─────┤ √X ├──────┤ Rz(3.3679) ├──■───────┤ √X ├──────■──»
# «                ┌───┴────┴───┐  └────────────┘┌─┴─┐┌────┴────┴───┐┌─┴─┐»
# «      q_2 -> 4 ─┤ Rz(-1.009) ├────────────────┤ X ├┤ Rz(0.31311) ├┤ X ├»
# «                └────────────┘                └───┘└─────────────┘└───┘»
# «                                                                           »
# «ancilla_0 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌─────────────┐┌────┐┌─────────────┐ ┌────┐  ┌────────────┐ »
# «      q_3 -> 1 ┤ Rz(-2.6101) ├┤ √X ├┤ Rz(-2.4136) ├─┤ √X ├──┤ Rz(1.7109) ├─»
# «               ├─────────────┤├────┤├─────────────┴┐├────┤ ┌┴────────────┤ »
# «      q_1 -> 2 ┤ Rz(-1.6335) ├┤ √X ├┤ Rz(-0.91263) ├┤ √X ├─┤ Rz(-2.4786) ├─»
# «               ├─────────────┤├────┤├──────────────┤├────┤ └┬───────────┬┘ »
# «      q_0 -> 3 ┤ Rz(-1.6002) ├┤ √X ├┤ Rz(-0.62343) ├┤ √X ├──┤ Rz(-1.77) ├──»
# «               ├─────────────┤├────┤├─────────────┬┘├────┤┌─┴───────────┴─┐»
# «      q_2 -> 4 ┤ Rz(-2.9082) ├┤ √X ├┤ Rz(-1.4445) ├─┤ √X ├┤ Rz(-0.069343) ├»
# «               └─────────────┘└────┘└─────────────┘ └────┘└───────────────┘»
# «                                                                            »
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌───┐┌──────────────┐              ┌───┐┌──────────────┐┌───┐»
# «      q_3 -> 1 ┤ X ├┤ Rz(-0.74808) ├──────────────┤ X ├┤ Rz(0.053196) ├┤ X ├»
# «               └─┬─┘└────┬────┬────┘┌────────────┐└─┬─┘└────┬────┬────┘└─┬─┘»
# «      q_1 -> 2 ──■───────┤ √X ├─────┤ Rz(3.1501) ├──■───────┤ √X ├───────■──»
# «                         ├────┤     ├────────────┤          ├────┤          »
# «      q_0 -> 3 ──■───────┤ √X ├─────┤ Rz(3.3194) ├──■───────┤ √X ├───────■──»
# «               ┌─┴─┐ ┌───┴────┴───┐ └────────────┘┌─┴─┐┌────┴────┴───┐ ┌─┴─┐»
# «      q_2 -> 4 ┤ X ├─┤ Rz(1.0773) ├───────────────┤ X ├┤ Rz(0.64583) ├─┤ X ├»
# «               └───┘ └────────────┘               └───┘└─────────────┘ └───┘»
# «                                                                              »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────────────»
# «               ┌─────────────┐┌────┐┌─────────────┐┌────┐┌──────────────┐     »
# «      q_3 -> 1 ┤ Rz(-2.4401) ├┤ √X ├┤ Rz(-1.9112) ├┤ √X ├┤ Rz(-0.86058) ├──■──»
# «               ├─────────────┤├────┤├─────────────┤├────┤├─────────────┬┘  │  »
# «      q_1 -> 2 ┤ Rz(0.25766) ├┤ √X ├┤ Rz(-1.2994) ├┤ √X ├┤ Rz(0.11905) ├───┼──»
# «               └┬────────────┤├────┤├─────────────┤├────┤└┬────────────┤ ┌─┴─┐»
# «      q_0 -> 3 ─┤ Rz(2.3151) ├┤ √X ├┤ Rz(-1.7604) ├┤ √X ├─┤ Rz(1.2314) ├─┤ X ├»
# «                ├────────────┤├────┤├─────────────┤├────┤┌┴────────────┤ └───┘»
# «      q_2 -> 4 ─┤ Rz(2.0246) ├┤ √X ├┤ Rz(-1.9203) ├┤ √X ├┤ Rz(-1.0135) ├──────»
# «                └────────────┘└────┘└─────────────┘└────┘└─────────────┘      »
# «                                                                     »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────»
# «                    ┌────┐    ┌────────────┐          ┌────┐         »
# «      q_3 -> 1 ─────┤ √X ├────┤ Rz(3.3027) ├──■───────┤ √X ├──────■──»
# «                    └────┘    └────────────┘  │       └────┘      │  »
# «      q_1 -> 2 ───────────────────────────────┼───────────────────┼──»
# «               ┌─────────────┐              ┌─┴─┐┌─────────────┐┌─┴─┐»
# «      q_0 -> 3 ┤ Rz(0.61821) ├──────────────┤ X ├┤ Rz(0.26105) ├┤ X ├»
# «               └─────────────┘              └───┘└─────────────┘└───┘»
# «      q_2 -> 4 ──────────────────────────────────────────────────────»
# «                                                                     »
# «                                                                             »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────────────»
# «               ┌────────────┐┌────┐┌─────────────┐┌────┐ ┌───────────┐  ┌───┐»
# «      q_3 -> 1 ┤ Rz(2.0842) ├┤ √X ├┤ Rz(-1.1588) ├┤ √X ├─┤ Rz(1.499) ├──┤ X ├»
# «               └────────────┘└────┘└─────────────┘└────┘ └───────────┘  └─┬─┘»
# «      q_1 -> 2 ───────────────────────────────────────────────────────────■──»
# «               ┌────────────┐┌────┐┌─────────────┐┌────┐┌──────────────┐     »
# «      q_0 -> 3 ┤ Rz(1.8727) ├┤ √X ├┤ Rz(-2.1148) ├┤ √X ├┤ Rz(-0.62881) ├──■──»
# «               └────────────┘└────┘└─────────────┘└────┘└──────────────┘┌─┴─┐»
# «      q_2 -> 4 ─────────────────────────────────────────────────────────┤ X ├»
# «                                                                        └───┘»
# «                                                                    »
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────»
# «                    ┌───┐┌─────────────┐┌────┐┌─────────────┐ ┌────┐»
# «      q_3 -> 1 ──■──┤ X ├┤ Rz(-1.8256) ├┤ √X ├┤ Rz(-2.6029) ├─┤ √X ├»
# «               ┌─┴─┐└─┬─┘├─────────────┤├────┤├─────────────┤ ├────┤»
# «      q_1 -> 2 ┤ X ├──■──┤ Rz(-1.7236) ├┤ √X ├┤ Rz(-1.9338) ├─┤ √X ├»
# «               ├───┤     └┬────────────┤├────┤├─────────────┤ ├────┤»
# «      q_0 -> 3 ┤ X ├──■───┤ Rz(2.8735) ├┤ √X ├┤ Rz(-1.8954) ├─┤ √X ├»
# «               └─┬─┘┌─┴─┐ ├────────────┤├────┤├─────────────┴┐├────┤»
# «      q_2 -> 4 ──■──┤ X ├─┤ Rz(1.0034) ├┤ √X ├┤ Rz(-0.78089) ├┤ √X ├»
# «                    └───┘ └────────────┘└────┘└──────────────┘└────┘»
# «                                                                      »
# «ancilla_0 -> 0 ───────────────────────────────────────────────────────»
# «               ┌─────────────┐           ┌────┐    ┌────────────┐     »
# «      q_3 -> 1 ┤ Rz(-2.1453) ├───■───────┤ √X ├────┤ Rz(3.1913) ├──■──»
# «               ├─────────────┤   │       └────┘    └────────────┘  │  »
# «      q_1 -> 2 ┤ Rz(-2.8154) ├───┼─────────────────────────────────┼──»
# «               ├─────────────┴┐┌─┴─┐┌─────────────┐              ┌─┴─┐»
# «      q_0 -> 3 ┤ Rz(-0.45085) ├┤ X ├┤ Rz(0.79768) ├──────────────┤ X ├»
# «               └┬────────────┬┘└───┘└─────────────┘              └───┘»
# «      q_2 -> 4 ─┤ Rz(1.4991) ├────────────────────────────────────────»
# «                └────────────┘                                        »
# «                                                                             »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────────────»
# «                    ┌────┐          ┌────────────┐┌────┐┌─────────────┐┌────┐»
# «      q_3 -> 1 ─────┤ √X ├──────■───┤ Rz(-1.301) ├┤ √X ├┤ Rz(-1.3272) ├┤ √X ├»
# «                    └────┘      │   └────────────┘└────┘└─────────────┘└────┘»
# «      q_1 -> 2 ─────────────────┼────────────────────────────────────────────»
# «               ┌─────────────┐┌─┴─┐┌─────────────┐┌────┐┌─────────────┐┌────┐»
# «      q_0 -> 3 ┤ Rz(0.37951) ├┤ X ├┤ Rz(-1.8437) ├┤ √X ├┤ Rz(-2.0467) ├┤ √X ├»
# «               └─────────────┘└───┘└─────────────┘└────┘└─────────────┘└────┘»
# «      q_2 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                                     »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────»
# «                ┌───────────┐ ┌───┐┌─────────────┐              ┌───┐»
# «      q_3 -> 1 ─┤ Rz(2.966) ├─┤ X ├┤ Rz(-0.7858) ├──────────────┤ X ├»
# «                └───────────┘ └─┬─┘└────┬────┬───┘┌────────────┐└─┬─┘»
# «      q_1 -> 2 ─────────────────■───────┤ √X ├────┤ Rz(3.3792) ├──■──»
# «               ┌─────────────┐          ├────┤    ├────────────┤     »
# «      q_0 -> 3 ┤ Rz(0.34253) ├──■───────┤ √X ├────┤ Rz(3.4163) ├──■──»
# «               └─────────────┘┌─┴─┐┌────┴────┴───┐└────────────┘┌─┴─┐»
# «      q_2 -> 4 ───────────────┤ X ├┤ Rz(0.63015) ├──────────────┤ X ├»
# «                              └───┘└─────────────┘              └───┘»
# «                                                                         »
# «ancilla_0 -> 0 ──────────────────────────────────────────────────────────»
# «                ┌────────────┐ ┌───┐ ┌────────────┐ ┌────┐┌─────────────┐»
# «      q_3 -> 1 ─┤ Rz(0.2742) ├─┤ X ├─┤ Rz(1.3039) ├─┤ √X ├┤ Rz(-2.1332) ├»
# «                └───┬────┬───┘ └─┬─┘┌┴────────────┤ ├────┤├─────────────┤»
# «      q_1 -> 2 ─────┤ √X ├───────■──┤ Rz(-2.1823) ├─┤ √X ├┤ Rz(-1.0091) ├»
# «                    ├────┤          └┬────────────┤ ├────┤├─────────────┤»
# «      q_0 -> 3 ─────┤ √X ├───────■───┤ Rz(1.6526) ├─┤ √X ├┤ Rz(-1.4283) ├»
# «               ┌────┴────┴────┐┌─┴─┐┌┴────────────┴┐├────┤├─────────────┤»
# «      q_2 -> 4 ┤ Rz(0.035869) ├┤ X ├┤ Rz(-0.98503) ├┤ √X ├┤ Rz(-1.4632) ├»
# «               └──────────────┘└───┘└──────────────┘└────┘└─────────────┘»
# «
# «ancilla_0 -> 0 ─────────────────────
# «               ┌────┐┌─────────────┐
# «      q_3 -> 1 ┤ √X ├┤ Rz(-1.2848) ├
# «               ├────┤├─────────────┤
# «      q_1 -> 2 ┤ √X ├┤ Rz(-2.9049) ├
# «               ├────┤└┬────────────┤
# «      q_0 -> 3 ┤ √X ├─┤ Rz(2.6591) ├
# «               ├────┤ ├────────────┤
# «      q_2 -> 4 ┤ √X ├─┤ Rz(2.2594) ├
# «               └────┘ └────────────┘
